# %% [markdown]
# # Data mining and visualization project using meteorite data

# %% [markdown]
# By L.D.<p>
# <i>
# First version 15-04-2019<br>
# Revised 16-04-2020</i>

# %% [markdown]
# Data source: https://www.kaggle.com/nasa/meteorite-landings

# %% [markdown]
# ## Importing modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Settings
save = False  # Change to 'True' to export and save all of the figures
dpi = 200  # Set dpi settings for saving a .png image

# %% [markdown]
# ## Importing data

# %%
df = pd.read_csv(r'C:\Users\Lukas\Meteor-data-visualization\Meteorite_Data.csv')

# %% [markdown]
# ## Data cleaning

# %%
df.head(3)
# Out:
#      name  id nametype recclass      mass  fall    year    reclat    reclong  \
# 0  Aachen   1    Valid       L5      21.0  Fell  1880.0  50.77500    6.08333
# 1  Aarhus   2    Valid       H6     720.0  Fell  1951.0  56.18333   10.23333
# 2    Abee   6    Valid      EH4  107000.0  Fell  1952.0  54.21667 -113.00000
#
#                 GeoLocation
# 0     (50.775000, 6.083330)
# 1    (56.183330, 10.233330)
# 2  (54.216670, -113.000000)

# %%
df.describe()
# Out:
#                  id          mass          year        reclat       reclong
# count  45716.000000  4.558500e+04  45428.000000  38401.000000  38401.000000
# mean   26889.735104  1.327808e+04   1991.772189    -39.122580     61.074319
# std    16860.683030  5.749889e+05     27.181247     46.378511     80.647298
# min        1.000000  0.000000e+00    301.000000    -87.366670   -165.433330
# 25%    12688.750000  7.200000e+00   1987.000000    -76.714240      0.000000
# 50%    24261.500000  3.260000e+01   1998.000000    -71.500000     35.666670
# 75%    40656.750000  2.026000e+02   2003.000000      0.000000    157.166670
# max    57458.000000  6.000000e+07   2501.000000     81.166670    354.473330

# %% [markdown]
# ##### Generating a mass variable that is in kilograms instead of grams

# %%
df['masskg'] = df['mass'] / 1000

# %% [markdown]
# ##### Splitting the GeoLocation into two separate variables

# %%
df[['Latitude','Longtitude']] = df.GeoLocation.str.split(" ",expand=True,)

# %% [markdown]
# ##### Removing parentheses and commas from Latitude and Longtitude

# %%
df['Latitude'] = df['Latitude'].str.replace(r'(', '').str.strip()
df['Latitude'] = df['Latitude'].str.replace(r',', '').str.strip()
df['Longtitude'] = df['Longtitude'].str.replace(r')', '').str.strip()

# %% [markdown]
# ##### Dropping unneeded columns

# %%
df = df.drop(['id', 'name', 'nametype', 'recclass', 'GeoLocation', 'reclat', 'reclong', 'mass'], axis=1)

# %% [markdown]
# ##### Drop rows with missing values

# %%
df.count()
# Out:
# fall          45716
# year          45428
# masskg        45585
# Latitude      38401
# Longtitude    38401
# dtype: int64

# %%
df = df[pd.notnull(df['Latitude'])]
df = df[pd.notnull(df['Longtitude'])]
df = df[pd.notnull(df['fall'])]
df = df[pd.notnull(df['masskg'])]
df = df[pd.notnull(df['year'])]

# %%
df.count()
# Out:
# fall          38116
# year          38116
# masskg        38116
# Latitude      38116
# Longtitude    38116
# dtype: int64

# %% [markdown]
# ##### Remove incorrect years, locations and coordinates as instructed by data set provider

# %%
df = df.drop(df[df.year < 861].index)
df = df.drop(df[df.year > 2016].index)
df = df.drop(df[df.masskg <= 0.00001].index)

# %%
df = df.loc[df['Latitude'] != '0', :]
df = df.loc[df['Longtitude'] != '0', :]

# %%
# Converting 'str' pandas dataframe into float numpy array
lat = df['Latitude'].values
lon = df['Longtitude'].values
lat = lat.astype(np.float)
lon = lon.astype(np.float)

# %% [markdown]
# ##### Splitting the dataset into categories of meteors that were seen vs that were found

# %% [markdown]
# Meteors that were seen

# %%
df.loc[df['fall'] == 'Fell', :].count()
# Out:
# fall          1064
# year          1064
# masskg        1064
# Latitude      1064
# Longtitude    1064
# dtype: int64

# %% [markdown]
# Meteors that were found

# %%
df.loc[df['fall'] == 'Found', :].count()
# Out:
# fall          37029
# year          37029
# masskg        37029
# Latitude      37029
# Longtitude    37029
# dtype: int64

# %% [markdown]
# Splitting the dataset

# %%
df_fell = df.loc[df['fall'] == 'Fell', :]
df_found = df.loc[df['fall'] == 'Found', :]

# %% [markdown]
# ##### Current data table

# %%
df.head(3)
# Out:
#    fall    year   masskg   Latitude   Longtitude
# 0  Fell  1880.0    0.021  50.775000     6.083330
# 1  Fell  1951.0    0.720  56.183330    10.233330
# 2  Fell  1952.0  107.000  54.216670  -113.000000

# %%
df['year'].describe()
# Out:
# count    38093.000000
# mean      1990.012758
# std         24.800981
# min       1399.000000
# 25%       1986.000000
# 50%       1996.000000
# 75%       2002.000000
# max       2013.000000
# Name: year, dtype: float64

# %%
df['masskg'].describe()
# Out:
# count    38093.000000
# mean        15.609702
# std        628.863155
# min          0.000013
# 25%          0.006670
# 50%          0.029100
# 75%          0.187700
# max      60000.000000
# Name: masskg, dtype: float64

# %% [markdown]
# ## Visual data exploration

# %% [markdown]
# #### How many meteors have we observed?

# %% [markdown]
# ##### Amount of meteor sighting by year

# %%
# Setting figure size
plt.figure(figsize=(8, 4))

# Histogram of years 1600 to 2016
plt.hist(df.year, log=True, color='#0504aa', edgecolor='white')

# Setting axis titles
plt.title("Histogram of meteor sightings for years 1600 to 2016", fontsize=18)
plt.xlabel("Year", fontsize=15)
plt.ylabel("Amount of sightings log", fontsize=15)

# Removing top and right part of the frame
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Saving the figure

# Saving the figure
if save == True:
    plt.savefig('Amount of sightings per year (hist) (all years).png', dpi=600)

# %% [markdown]
# It is interesting that the observation rate grew exponentially but uniformly, even though no modern technology was present for hundreds of years prior. There have still been ~100 reported cases around 1800's.

# %% [markdown]
# #### What is the usual mass?

# %% [markdown]
# ##### Meteor size distribution

# %%
# Setting figure size
plt.figure(figsize=(12, 6))

# Plotting histogram of mass
plt.hist(df.masskg, bins=70, log=True, color='#0504aa', edgecolor='white')

# Setting axis titles
plt.title("Histogram of mass", fontsize=22)
plt.xlabel("Mass", fontsize=18)
plt.ylabel("Count", fontsize=18)

# Removing top and right part of the frame
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Saving the figure
if save == True:
    plt.savefig('Mass (hist) (all).png', dpi=600)

# %% [markdown]
# There have been a few dozen cases, where meteors anywhere from 1 to 60 tonnes have been documented, however, we can observe that most are quite tiny. So, let's zoom in a little bit:

# %%
# Setting figure size
plt.figure(figsize=(12, 6))

masslow = df.loc[df['masskg'] < 5, 'masskg']

# Plotting histogram of mass
plt.hist(masslow, bins=3000, color='#0504aa', edgecolor='white')

# Setting axis titles
plt.title("Histogram of mass", fontsize=22)
plt.xlabel("Mass", fontsize=18)
plt.ylabel("Count", fontsize=18)

# Removing top and right part of the frame
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Setting axis limits
plt.xlim(0, 0.25)

# Saving the figure
if save == True:
    plt.savefig('Mass (hist) (up to 10 tonnes).png', dpi=600)

# %% [markdown]
# The absolute majority of meteors seem to be tiny, anywhere from a few grams to a few hundred.

# %% [markdown]
# #### Does mass differ throughout the years?

# %% [markdown]
# ##### Meteor size by year

# %% [markdown]
# Let's try to see if the recorded sizes of meteors differ throughout the years.

# %%
# Setting figure size
a = plt.figure(figsize=(12, 6))

# Plotting a scatter plot
plt.scatter(df.year, df.masskg, color='#0504aa', s=1)

# Setting axis titles
plt.title("Meteor size by year", fontsize=22)
plt.xlabel("Year", fontsize=18)
plt.ylabel("Meteor mass in KG", fontsize=18)

# Removing top and right part of the frame
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Saving the figure
if save == True:
    plt.savefig('Mass by year.png', dpi=600)

# %% [markdown]
# Since there are so many observations, yet it is hard to visually tell if there's a difference in observed size distribution. However, we can exclude the year and mass outliers, and transform the mass variable to be more fitting.

# %% [markdown]
# ##### Meteor size by year: a closer look

# %%
# Setting figure size
plt.figure(figsize=(12, 6))

# Transforming mass (log)
log_mass = np.log(df['masskg'])

# Creating a scatter plot
plt.scatter(df.year, df.masskg, color='#0504aa', s=0.5)

# Setting axis titles
plt.title("Meteors by size for years 1600 to 2016", fontsize=22)
plt.xlabel("Year", fontsize=18)
plt.ylabel("Meteor mass in KG", fontsize=18)

# Setting axis limits
plt.xlim(1600, 2016)
plt.ylim(0, 100)

# Removing top and right part of the frame
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Saving the figure
if save == True:
    plt.savefig('Mass by year (up to 100kg) (all years).png', dpi=600)

# %% [markdown]
# Still not very useful, to try and spot patterns we'll try zooming in even more and log transforming the mass variable.

# %% [markdown]
# ##### Meteor size by year: relative mass

# %%
# Setting figure size
plt.figure(figsize=(12, 6))

##
log_mass_fell = np.log(df_fell['masskg']) + 10
log_mass_found = np.log(df_found['masskg']) + 10

# Creating a 'found' scatter plot
plt.scatter(df_found.year, log_mass_found, color='#0504aa', s=3, alpha=0.6)
# Creating a 'fell' scatter plot
plt.scatter(df_fell.year, log_mass_fell, color='red', s=3, alpha=0.6)

# Setting axis titles
plt.title("Meteors by size for years 1800 to 2016", fontsize=22)
plt.xlabel("Year", fontsize=18)
plt.ylabel("Relative mass (Log)", fontsize=18)

# Setting axis limits
plt.xlim(1800, 2016)
plt.ylim(0, 20)

# Removing top and right part of the frame
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Saving the figure
if save == True:
    plt.savefig('Mass by year (relative mass) (all years).png', dpi=600)

# %% [markdown]
# Red dot = Observed meteor<br>
# Blue dot = Found meteor<br>
# Note that the amount of observed meteors (red) hasn't really changed.

# %% [markdown]
# First we notice a sharp increase in recorded observations in a very short period of time around 1974 (specifically meteors that we're found), which started a whole new trend of documentation, meaning that, perhaps, some better tools or means of identification of extraterrestrial substance were discovered. This trend consistently continues up until the very latest year. Furthermore, a lot smaller meteors began being documented as well.

# %% [markdown]
# #### Map of impacts

# %% [markdown]
# ##### Worldwide meteor impacts

# %%
##### Setting figure size
plt.figure(figsize=(15, 8))

# Creating a projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Set background image (Check https://visibleearth.nasa.gov/collection/1484/blue-marble for more background images)
# ax.stock_img()  # Setting background to stock image

# Removing image size limits
from PIL import Image
Image.MAX_IMAGE_PIXELS = None
# Setting up the environment directory
import os  # Kernel needs to be reset if changes to image.json are made
os.environ["CARTOPY_USER_BACKGROUNDS"] = r'C:\Users\Lukas\OneDrive\Projects\WB\Articles\Data Analysis\Geographical data\Meteor_data_visualization-master\cartopy_metadata'
# Setting the image as a background
ax.background_img(name='BM', resolution='low')

# Removing everything but the scatter plot
plt.axis('off')

# Normalizing mass with square root, to correlate with marker size
df['sqrt_mass'] = df['masskg']**(1/2)

# Creating a scatter plot
plt.scatter(lon, lat, s=df.sqrt_mass*15, alpha=0.7, 
              marker='.', color='red', edgecolors='white', linewidths=0.5,
                transform=ccrs.PlateCarree())

# Saving the figure
if save == True:
    plt.savefig('World map w meteors.png', bbox_inches='tight', dpi=dpi)

# %% [markdown]
# We can see where the impacts are usually observed or found, and where the largest meteors struck.

# %% [markdown]
# #### Europe meteor impacts

# %%
# Setting figure size
plt.figure(figsize=(15, 8))

# Creating a projection
ax = plt.axes(projection=ccrs.Orthographic())

# Selecting coordinates of the area (https://www.openstreetmap.org/export)
# Latitude is height
lat_min = 35
lat_max = 70
lon_min = -18
lon_max = 50
# Zooming in on a specified area
ax.set_extent([lon_min, lon_max, lat_min, lat_max])

# Setting the image as a background
ax.background_img(name='BM', resolution='low')

# Removing everything but the scatter plot
plt.axis('off')

# Creating country borders
ax.add_feature(cfeature.BORDERS.with_scale('10m'))
# Creating coastline borders
ax.coastlines(resolution='10m')

# Creating a scatter plot
plt.scatter(lon, lat, s=df.sqrt_mass*20, alpha=0.8, 
              marker='.', color='red', edgecolors='white', linewidths=0.7,
                transform=ccrs.PlateCarree())

# Saving the figure
if save == True:
    plt.savefig('Europe map w meteors.png', bbox_inches='tight', dpi=dpi)

# %% [markdown]
# #### The world through our observations

# %% [markdown]
# And here is our world drawn by our own observations of meteors.

# %%
# Setting figure size
plt.figure(figsize=(15, 8))

# Removing everything but the scatter plot
plt.axis('off')

# Creating a scatter plot
plt.scatter(lon, lat, color='darkblue', s=4,
             alpha=0.5, edgecolor='black', linewidth=0.05)

# Saving the figure
if save == True:
    plt.savefig('Scatter map w meteors.png', bbox_inches='tight', dpi=dpi)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In the end, the areas that have:
# <br>- Higher population density
# <br>- Non-humid & clear skies
# <br>- Infrastructure for reporting
# <br> Have a lot higher amount of records, however, we know that meteors hit earth rather uniformly (except for a slight difference around the poles), therefore, we can probably assume that the amount of small impacts (the ones that can't be traced from a distance via satellites or observatories) is uniform throughout earth AND as dense as the densest impact point on the map.
